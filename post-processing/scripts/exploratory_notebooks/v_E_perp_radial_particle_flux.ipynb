# %%
# Imports.
import numpy as np;
import xarray as xr;
import matplotlib.pyplot as plt;
import h5_reader_xr as reader;
import rprof_utilities as utils;

# Styling.
plt.style.use("ggplot");

# %%
# Test inputs - delete when done!
directory_path = "/zhisongqu_data/seth/GYSELA/raw/fresh_batch_7.0/DN_FLUXDRIVEN_GAM_CIRCULARTEST_Q3.5";
data_arrays = reader.fetch_rprof_data(directory_path, dataset = "GammaGC_vE_r_FSavg");
# Out:
# The given directory '/zhisongqu_data/seth/GYSELA/raw/fresh_batch_7.0/DN_FLUXDRIVEN_GAM_CIRCULARTEST_Q3.5/sp0/rprof' could not be resolved.
# No h5 files could be retrieved from /zhisongqu_data/seth/GYSELA/raw/fresh_batch_7.0/DN_FLUXDRIVEN_GAM_CIRCULARTEST_Q3.5/sp0/rprof.

# %%
def plot_radial_particle_flux_time_series(rprof_list, dt_diag, effective_radius = None, log_scale = False):	
	# Stack into (time, r) array.
	particle_flux_series = xr.concat(rprof_list, dim = "time");
	
	if effective_radius is not None:
		particle_flux_series = utils.slice_at_effective_radius(particle_flux_series, effective_radius);
	
	time_range = utils.generate_time_range_by_series(particle_flux_series, dt_diag);

	# Figure plotting logic.
	operation = plt.semilogy if log_scale else plt.plot;
	rho_label = f"$\\rho = {effective_radius}$" if effective_radius is not None else "all radii";
	plt.figure(figsize=(10, 5));
	operation(time_range, particle_flux_series, color = "blue", lw = 1.0, label = r"$\Gamma_{E \times B}$");
	plt.title(rf"Radial $E \times B$ Particle Flux, {rho_label}", fontsize = 14);
	plt.xlabel("Time [GYSELA code units]", fontsize = 12);
	plt.ylabel(r"$\Gamma_{E \times B}$", fontsize = 12);
	plt.legend();
	plt.show();

plot_radial_particle_flux_time_series(data_arrays, dt_diag = 50, effective_radius = 0.7, log_scale = False);
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~/modules/miniforge3/envs/gysela_3.13/lib/python3.13/site-packages/xarray/structure/concat.py:287, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs, create_index_for_new_dim)
#     286 try:
# --> 287     first_obj, objs = utils.peek_at(objs)
#     288 except StopIteration as err:
#
# File ~/modules/miniforge3/envs/gysela_3.13/lib/python3.13/site-packages/xarray/core/utils.py:287, in peek_at(iterable)
#     286 gen = iter(iterable)
# --> 287 peek = next(gen)
#     288 return peek, itertools.chain([peek], gen)
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 21
#      18 	plt.legend();
#      19 	plt.show();
# ---> 21 plot_radial_particle_flux_time_series(data_arrays, dt_diag = 50, effective_radius = 0.7, log_scale = False);
#
# Cell In[3], line 3, in plot_radial_particle_flux_time_series(rprof_list, dt_diag, effective_radius, log_scale)
#       1 def plot_radial_particle_flux_time_series(rprof_list, dt_diag, effective_radius = None, log_scale = False):
#       2 	# Stack into (time, r) array.
# ----> 3 	particle_flux_series = xr.concat(rprof_list, dim = "time");
#       5 	if effective_radius is not None:
#       6 		particle_flux_series = utils.slice_at_effective_radius(particle_flux_series, effective_radius);
#
# File ~/modules/miniforge3/envs/gysela_3.13/lib/python3.13/site-packages/xarray/structure/concat.py:289, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs, create_index_for_new_dim)
#     287     first_obj, objs = utils.peek_at(objs)
#     288 except StopIteration as err:
# --> 289     raise ValueError("must supply at least one object to concatenate") from err
#     291 if not isinstance(compat, CombineKwargDefault) and compat not in set(
#     292     _VALID_COMPAT
#     293 ) - {"minimal"}:
#     294     raise ValueError(
#     295         f"compat={compat!r} invalid: must be 'broadcast_equals', 'equals', 'identical', 'no_conflicts' or 'override'"
#     296     )
#
# ValueError: must supply at least one object to concatenate
