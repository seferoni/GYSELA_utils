# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def generate_hovmoller_matrix(phi2D_list):

	# Poloidal averaging, equivalent in function to flux-surface averaging. This isolates the m = 0 zonal component.
	# Intuitively speaking, this also 'truncates' the circular geometry into one-dimensional radial strips.
	radial_strips = [np.mean(phi2D_list, axis = 1) for phi2D_array in phi2D_list];
	hovmoller_matrix = np.stack(radial_strips);
	return hovmoller_matrix;

def plot_hovmoller(phi2D_list):
	
	hovmoller_matrix = generate_hovmoller_matrix(phi2D_list);
	# TODO:
